# %%
# Imports #

import numpy as np
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, ReLU, MaxPool2D, BatchNormalization, Concatenate
from tensorflow.keras.models import Model

# %%
# CONSTANTS #

MODEL_DIR = "/Users/pujan/Grad/Projects/Research/FOLO/Models"

IMAGE_X = 300
IMAGE_Y = 300

# %%
# TF #

def loss_p(y_true, y_pred):
    loss = tf.losses.binary_crossentropy(y_true, y_pred)
    return tf.reduce_sum(loss)

# %%
# LOAD MODEL #
MODEL_FILE = 

with tf.keras.utils.custom_object_scope({
        'loss_p': loss_p,
}):
    model = tf.keras.models.load_model(MODEL_FILE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # LOAD MODEL #
# ----> 2 MODEL_FILE = MODEL_DIR +'/FOLO.keras'
#       4 with tf.keras.utils.custom_object_scope({
#       5         'loss_p': loss_p,
#       6 }):
#       7     model = tf.keras.models.load_model(MODEL_FILE)
#
# NameError: name 'MODEL_DIR' is not defined
